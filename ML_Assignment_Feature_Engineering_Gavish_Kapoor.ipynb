# %% [markdown]
# <a href="https://colab.research.google.com/github/GavishKapoor/ML-Assignment-Feature-Engineering-Gavish-Kapoor.ipynb/blob/main/ML_Assignment_Feature_Engineering_Gavish_Kapoor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. **What is a parameter?**
#
# A parameter is an internal variable in a machine learning model that is learned from training data. For example, weights in linear regression.
#
# ---
#
# ### 2. **What is correlation?**
#
# Correlation shows the relationship between two variables — how one changes when the other changes.
#
# ---
#
# ### 3. **What does negative correlation mean?**
#
# Negative correlation means when one variable increases, the other decreases.
#
# ---
#
# ### 4. **Define Machine Learning. What are the main components in Machine Learning?**
#
# Machine Learning is when computers learn from data to make predictions.
# Main components:
#
# * Data
# * Model
# * Training
# * Testing
# * Evaluation
#
# ---
#
# ### 5. **How does loss value help in determining whether the model is good or not?**
#
# Loss shows how wrong the model's predictions are. A low loss means the model is doing well.
#
# ---
#
# ### 6. **What are continuous and categorical variables?**
#
# * **Continuous**: Numbers that can take any value (like height, weight).
# * **Categorical**: Values in groups (like color: red, blue).
#
# ---
#
# ### 7. **How do we handle categorical variables in Machine Learning? What are the common techniques?**
#
# We convert categories to numbers using:
#
# * **Label Encoding**
# * **One-Hot Encoding**
#
# ---
#
# ### 8. **What do you mean by training and testing a dataset?**
#
# * **Training**: Teaching the model with data.
# * **Testing**: Checking how well the model learned by using new data.
#
# ---
#
# ### 9. **What is sklearn.preprocessing?**
#
# It is a module in scikit-learn used to prepare and clean data (like scaling or encoding).
#
# ---
#
# ### 10. **What is a Test set?**
#
# The part of data used to check how good the model is after training.
#
# ---
#
# ### 11. **How do we split data for model fitting (training and testing) in Python?**
#
# Using:
#
# ```python
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# ```
#
# ---
#
# ### 12. **How do you approach a Machine Learning problem?**
#
# 1. Understand the problem
# 2. Collect data
# 3. Clean data
# 4. Do EDA
# 5. Train model
# 6. Test and evaluate
# 7. Improve if needed
#
# ---
#
# ### 13. **Why do we have to perform EDA before fitting a model to the data?**
#
# EDA (Exploratory Data Analysis) helps us understand the data and find errors or patterns.
#
# ---
#
# ### 14. **How can you find correlation between variables in Python?**
#
# Use:
#
# ```python
# df.corr()
# ```
#
# ---
#
# ### 15. **What is causation? Explain difference between correlation and causation with an example.**
#
# * **Causation**: One thing **causes** another.
# * **Correlation**: Two things move together but one doesn’t cause the other.
#   Example: Ice cream sales and sunburns are correlated but eating ice cream doesn't **cause** sunburn.
#
# ---
#
# ### 16. **What is an Optimizer? What are different types of optimizers? Explain each with an example.**
#
# Optimizers improve the model during training.
# Common types:
#
# * **SGD (Stochastic Gradient Descent)** – simple, updates model slowly
# * **Adam** – faster and smarter optimizer
#   Example:
#
# ```python
# optimizer = tf.keras.optimizers.Adam()
# ```
#
# ---
#
# ### 17. **What is sklearn.linear\_model?**
#
# It is a module in scikit-learn for linear models like LinearRegression and LogisticRegression.
#
# ---
#
# ### 18. **What does model.fit() do? What arguments must be given?**
#
# It trains the model.
# Arguments:
#
# * Training data (X)
# * Target labels (y)
#
# Example:
#
# ```python
# model.fit(X_train, y_train)
# ```
#
# ---
#
# ### 19. **What does model.predict() do? What arguments must be given?**
#
# It makes predictions using the trained model.
# Argument: test data (X)
#
# Example:
#
# ```python
# model.predict(X_test)
# ```
#
# ---
#
# ### 20. **What is feature scaling? How does it help in Machine Learning?**
#
# Feature scaling changes the range of values to be similar. It helps the model learn better and faster.
#
# ---
#
# ### 21. **How do we perform scaling in Python?**
#
# Using:
#
# ```python
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)
# ```
#
# ---
#
# ### 22. **Explain data encoding?**
#
# It converts text (categories) into numbers so that models can understand.
#
# ---
